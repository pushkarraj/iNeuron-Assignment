# %% [markdown]
# # Assignment 1 Solutions

# %% [markdown]
# #### 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# `*`,`'hello'`, `-87.8`,`-`,`/`,`+`,`6`
#
# **Ans:** There are a total of 4 Values and 3 Expressions, They are:
# **Expression:** `*`,`-`,`/`,`+` **Values:** `'hello'`, `87.8`, `6`

# %% [markdown]
# #### 2. What is the difference between string and variable?
# **Ans:** A Variable is used to store of information, and a String is a type of information you would store in a Variable. A String is a group of characters or a single character usually enclosed in Double quotes `" "` or single quotes `' '`.These characters may be alphabates,words or numbers.

# %% [markdown]
# #### 3. Describe three different Data Types ?
# **Ans:** Three fundamental Data types in python are `int`, `float`, `string`.
# 1. **int data type**: We can use int data type to represent integers.
# 2. **float data type**: We can use float data type to represent Rational numbers.(decimals)
# 3. **string data type**: We use string data type to represent alphabatic,nummeric or alphanumeric characters.

# %%
# Example for int data type
int_num=47
print(int_num, type(int_num))
# Example for float data type
flo_num=1.2
print(flo_num, type(flo_num))
# Example for string data type
string='sudhanhu is no 1'
print(string, type(string))
# Out:
# 47 <class 'int'>
# 1.2 <class 'float'>
# sudhanhu is no 1 <class 'str'>

# %% [markdown]
# #### 4. What is an expression made up of? What do all expressions do?
# **Ans:** A combination of operators and operands interpreted to produce a value. Some of these operators are `/`,`+`,`-`,`&`,`|`,`and`,`or`

# %%
12>5 and 6>5 # Is an Expression, The Python Interpreter Evaluates it to 0
# Out:
# True

# %% [markdown]
# #### 5.This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# **Ans:** An Expression is a sequence or combination of values, variables, operators and function calls that always produces or returns a result value.
#
# **eg:** 4*5+20-40 is an example of a expression
#
# A statement is a unit of code that has an effect, like creating a variable or displaying a value.When we type a statement,
# the interpreter executes it, which means that it does whatever the statement says. In general, statements don’t have values.
#
# **eg:** variable declaration and assignment are statements because they do not return a value.

# %%
#Example:
courseName = 'INeuron FullStack DataScience' # Is a Statement
print("Hello World !") # Is a Expression Statement
4*5+20-40 # Is a Expression
# Out:
# Hello World !
# 0

# %% [markdown]
# #### 6.After running the following code, what does the variable bacon contain?
# `bacon = 22`
# `bacon + 1`
#
# **Ans:** The variable `bacon` is set to `22` .The expression `bacon + 1` does not reassign the value in
# bacon (that would be the case if the expression is like `bacon = bacon + 1` instead of `bacon + 1`)

# %%
# Example
bacon=22
bacon+1
print(bacon)
# Out:
# 22

# %% [markdown]
# #### 7.What should the values of the following two terms be?
# `'spam'+'spamspam'`
# `'spam'*3`
#
# **Ans:** Both expressions evaluate to the string **`'spamspamspam'`**
# Where as the first expression follows `String Concatentation` and the second expression follows `String Multiplication`

# %%
print('spam'+'spamspam') # string concatenation
print('spam'*3) # string multiplication
# Out:
# spamspamspam
# spamspamspam

# %% [markdown]
# #### 8. Why is eggs a valid variable name while 100 is invalid?
# **Ans:** As per python,Variable names cannot begin with a number. The python rules for naming a variable are :-
# 1. Variable name must start with a letter or the underscore character.
# 2. Variable name cannot start with a number.
# 3. Variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, & _ ).
# 4. Variable names are case-sensitive (`name`, `INEURON` and `ineuron` are three different variables).
# 5. The reserved words(keywords) cannot be used naming the variable.

# %%
egg='Ineuron' # Valid variable Initilization
100='hello' # Invalid Variable Initilization
print(egg) #prints the value of egg ie Ineuron
print(100) # Raises a Syntax Error as 100 is not a valid variable name
# Out:
#   File "C:\Users\dnsingh\AppData\Local\Temp/ipykernel_6020/3634917690.py", line 2
#     100='hello' # Invalid Variable Initilization
#     ^
# SyntaxError: cannot assign to literal

# %% [markdown]
# #### 9.What three functions can be used to get the integer,floating-point number,or string version of a value?
# **Ans:** The `int()`,`float()`,and `str()`

# %%
# Examples:
print('int(10.0) -> ',int(10.0)) # int() function converts given float to int
print('float(10) -> ',float(10)) # float() function converts given int to float
print('str(10) -> ',str(10)) # str() function converts given int to string
# Out:
# int(10.0) ->  10
# float(10) ->  10.0
# str(10) ->  10

# %% [markdown]
# #### 10.Why does this expression cause an error? how can you fix it?
# `'I have eaten ' + 99 + 'burritos.'`
#
# **Ans:** This cause of error is 99.because 99 is not a string. 99 must be typecasted to a string to fix this error. the correct way is:
# **Input:** `'I have eaten ' + str(99) + 'burritos.'`
# **Output:** `'I have eaten 99 burritos.'`

# %%
#method1
'I have eaten '+str(99)+' burritos'
# Out:
# 'I have eaten 99 burritos'

# %%
#method2
'I have eaten '+'99'+' burritos'
# Out:
# 'I have eaten 99 burritos'
